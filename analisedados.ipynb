# %% [markdown]
# # Analise de dados

# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np
import streamlit as st

# %% [markdown]
# ### Read end process the databese

# %%
df = pd.read_csv(r"db/vgsales.csv")

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.groupby(by="Platform",as_index=False).count()[["Platform","Rank"]]
# Out:
#    Platform  Rank
# 0      2600   133
# 1       3DO     3
# 2       3DS   509
# 3        DC    52
# 4        DS  2163
# 5        GB    98
# 6       GBA   822
# 7        GC   556
# 8       GEN    27
# 9        GG     1
# 10      N64   319
# 11      NES    98
# 12       NG    12
# 13       PC   960
# 14     PCFX     1
# 15       PS  1196
# 16      PS2  2161
# 17      PS3  1329
# 18      PS4   336
# 19      PSP  1213
# 20      PSV   413
# 21      SAT   173
# 22      SCD     6
# 23     SNES   239
# 24     TG16     2
# 25       WS     6
# 26      Wii  1325
# 27     WiiU   143
# 28     X360  1265
# 29       XB   824
# 30     XOne   213
